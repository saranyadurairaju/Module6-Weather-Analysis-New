# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
#city_url = url + "&q=" + city.replace(" ","+")
#city_weather = requests.get(city_url).json()
#city_weather
#city_weather["coord"]
#city_weather["weather"][0]["description"]
city_data = []

for i in range(5):
    city_url = url + "&q=" + city.replace(" ","+")

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desp = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        print(city.title())
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desp})

    # If an error is experienced, skip the city.
    except:
        pass

city_data
# Out:
# Tahe
# Tahe
# Tahe
# Tahe
# Tahe
# [{'City': 'Tahe',
#   'Country': 'CN',
#   'Lat': 52.3333,
#   'Lng': 124.7333,
#   'Max Temp': 59.14,
#   'Humidity': 97,
#   'Cloudiness': 7,
#   'Wind Speed': 3.56,
#   'Current Description': 'clear sky'},
#  {'City': 'Tahe',
#   'Country': 'CN',
#   'Lat': 52.3333,
#   'Lng': 124.7333,
#   'Max Temp': 59.14,
#   'Humidity': 97,
#   'Cloudiness': 7,
#   'Wind Speed': 3.56,
#   'Current Description': 'clear sky'},
#  {'City': 'Tahe',
#   'Country': 'CN',
#   'Lat': 52.3333,
#   'Lng': 124.7333,
#   'Max Temp': 59.14,
#   'Humidity': 97,
#   'Cloudiness': 7,
#   'Wind Speed': 3.56,
#   'Current Description': 'clear sky'},
#  {'City': 'Tahe',
#   'Country': 'CN',
#   'Lat': 52.3333,
#   'Lng': 124.7333,
#   'Max Temp': 59.14,
#   'Humidity': 97,
#   'Cloudiness': 7,
#   'Wind Speed': 3.56,
#   'Current Description': 'clear sky'},
#  {'City': 'Tahe',
#   'Country': 'CN',
#   'Lat': 52.3333,
#   'Lng': 124.7333,
#   'Max Temp': 59.14,
#   'Humidity': 97,
#   'Cloudiness': 7,
#   'Wind Speed': 3.56,
#   'Current Description': 'clear sky'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#    City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Tahe      CN  52.3333  124.7333     59.14        97           7
# 1  Tahe      CN  52.3333  124.7333     59.14        97           7
# 2  Tahe      CN  52.3333  124.7333     59.14        97           7
# 3  Tahe      CN  52.3333  124.7333     59.14        97           7
# 4  Tahe      CN  52.3333  124.7333     59.14        97           7
#
#    Wind Speed Current Description
# 0        3.56           clear sky
# 1        3.56           clear sky
# 2        3.56           clear sky
# 3        3.56           clear sky
# 4        3.56           clear sky

# %%
# Create an empty list to hold the weather data.
city_data = []

for i, city in enumerate(cities):

    city_url = url + "&q=" + city.replace(" ","+")

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desp = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        print(city.title())
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desp})

# If an error is experienced, skip the city.
    except:
        pass

print("-----------------------------")
# Out:
# Los Llanos De Aridane
# Coahuayana
# Rikitea
# Hefei
# Buala
# Esperance
# Nikolskoye
# Port Blair
# Ushuaia
# Saskylakh
# Albany
# Cidreira
# Andreapol
# Barrow
# Kapaa
# Sorland
# Lompoc
# Bredasdorp
# Thompson
# Lebu
# Tambopata
# Hermanus
# Thunder Bay
# Bardiyah
# Atuona
# Saldanha
# Chokurdakh
# Avarua
# Padilla
# Vilhena
# Christchurch
# Hilo
# Bengkulu
# Cacaopera
# Airai
# New Norfolk
# Oranjestad
# Stephenville
# Busselton
# San Cristobal
# Half Moon Bay
# Bayan
# Zhigansk
# Yellowknife
# San Patricio
# Luanda
# Ixtapa
# Cabo San Lucas
# Georgetown
# Port Elizabeth
# Tiksi
# Haines Junction
# Lagoa
# Faanui
# Minsk
# Strathpeffer
# Castro
# Havoysund
# Bluff
# Assiniboia
# Kavieng
# Qaanaaq
# Kaitangata
# Sistranda
# Mataura
# Mehamn
# Kilindoni
# Charlestown
# Salme
# Berlevag
# Westport
# Punta Arenas
# Kyshtovka
# Bambanglipuro
# Troitsk
# Quthing
# Raudeberg
# Kristiansund
# Te Anau
# Cachira
# Badnawar
# Nizhniy Baskunchak
# Minggang
# Acapulco
# Annau
# Tornio
# Pangkalanbuun
# Dharchula
# Morant Bay
# Pacific Grove
# Codrington
# Koindu
# Jerico
# Labuhan
# Kroonstad
# Bollnas
# Carutapera
# Bugene
# Kasongo-Lunda
# Coquimbo
# General Cepeda
# Venado Tuerto
# Walvis Bay
# Pontes E Lacerda
# Kalmunai
# Ileza
# Jabinyanah
# General Roca
# Starobaltachevo
# North Myrtle Beach
# Ulaanbaatar
# Keti Bandar
# Islamkot
# Jiuquan
# Arlit
# Senador Guiomard
# Pakxan
# Prince Rupert
# Esmeraldas
# Nalut
# Tanout
# Sayyan
# Boende
# Kamenka
# Evensk
# Santiago
# Dhidhdhoo
# Itaituba
# Port Augusta
# Mpophomeni
# Vanavara
# Laguna De Perlas
# Mangrol
# Gazojak
# Bairiki
# Faya
# Chifeng
# Jashpurnagar
# Saint-Augustin
# Verkhoyansk
# Banda Aceh
# Masoko
# Markapur
# Mucurapo
# Aksarka
# Ngunguru
# Chumikan
# Lucapa
# Karpathos
# Port-Cartier
# Santa Barbara
# Wenling
# Karaton
# Nelson Bay
# Katsina
# Shimoga
# Gazanjyk
# Lyubotyn
# Slupca
# Trairi
# Kavaratti
# Dolores Hidalgo
# Manga
# Qasigiannguit
# Kourou
# Vetluga
# Coro
# Axim
# Santiago De Cao
# Trabzon
# Bacolod
# Cassilandia
# Marawi
# Jati
# Matay
# Baile Olanesti
# Kon Tum
# Jaru
# Big Rapids
# Menongue
# Altus
# Dwarka
# Nantucket
# Jurm
# Akkermanovka
# Kharar
# Zheleznodorozhnyy
# Kurilsk
# Kuching
# Dalvik
# Bakel
# Parkes
# Sharjah
# Karratha
# Springville
# Saint-Francois
# Kharsawan
# Flinders
# Mikhaylovka
# Andra
# Buin
# Elko
# Pafos
# Narrabri
# La Ronge
# Hays
# Bontang
# Imbituba
# Maniitsoq
# Santa Marta
# Oussouye
# Kargasok
# Lanzhou
# Kaarina
# Porto Santo
# Bereda
# Ponta Delgada
# Chulym
# Tena
# Tshikapa
# Antofagasta
# Krasnoselkup
# Bonnyville
# Maicao
# Tabou
# East Wenatchee Bench
# Osorno
# Fort Nelson
# Quatre Cocos
# Hauterive
# Glarus
# Vieste
# Linxia
# Livermore
# Belaya Gora
# Jumla
# Nusaybin
# Bubaque
# Conde
# Katsuura
# Ustye
# Makaha
# Paraiso
# Ayorou
# Sangar
# Praia Da Vitoria
# Tahe
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Los Llanos De Aridane      ES  28.6585  -17.9182     69.55        91
# 1             Coahuayana      MX  18.7333 -103.6833     89.47        62
# 2                Rikitea      PF -23.1203 -134.9692     69.21        54
# 3                  Hefei      CN  31.8639  117.2808     77.02        94
# 4                  Buala      SB  -8.1450  159.5921     79.81        84
#
#    Cloudiness  Wind Speed Current Description
# 0          20       16.11          few clouds
# 1          37        6.04    scattered clouds
# 2           0        0.89           clear sky
# 3           0        4.47           clear sky
# 4          88        8.79          light rain

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file)
